# %%
import os
import pandas as pd

# %%
# Ensure GCP credentials are visible to pandas
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../secrets/sa-key.json"

BUCKET_NAME = "ecommerce-raw-data-mohammed"

# %%
# Stream Parquet files directly from GCS into DataFrames
df_meta = pd.read_parquet(f"gs://{BUCKET_NAME}/raw/metadata/all_beauty_metadata.parquet")
df_meta.head(5)
# Out:
#   main_category                                              title  \
# 0    All Beauty  Howard LC0008 Leather Conditioner, 8-Ounce (4-...
# 1    All Beauty  Yes to Tomatoes Detoxifying Charcoal Cleanser ...
# 2    All Beauty   Eye Patch Black Adult with Tie Band (6 Per Pack)
# 3    All Beauty  Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4...
# 4    All Beauty  Precision Plunger Bars for Cartridge Grips – 9...
#
#    average_rating  rating_number  \
# 0             4.8             10
# 1             4.5              3
# 2             4.4             26
# 3             3.1            102
# 4             4.3              7
#
#                                             features  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ['Material: 304 Stainless Steel; Brass tip'\n ...
#
# ...

# %%
# --- Metadata Inspection ---
print("=== METADATA SHAPE ===")
print(df_meta.shape)
# Out:
# === METADATA SHAPE ===
# (50, 16)

# %%
print("\n=== METADATA COLUMNS & TYPES ===")
print(df_meta.dtypes)
# Out:
# === METADATA COLUMNS & TYPES ===
# main_category          str
# title                  str
# average_rating     float64
# rating_number        int64
# features               str
# description            str
# price                  str
# images                 str
# videos                 str
# store                  str
# categories             str
# details                str
# parent_asin            str
# bought_together        str
# subtitle               str
# author                 str
# dtype: object

# %%
print("\n=== METADATA NULL VALUES ===")
print(df_meta.isnull().sum())
# Out:
# === METADATA NULL VALUES ===
# main_category       0
# title               0
# average_rating      0
# rating_number       0
# features            0
# description         0
# price               0
# images              0
# videos              0
# store               5
# categories          0
# details             0
# parent_asin         0
# bought_together    50
# subtitle           50
# author             50
# dtype: int64

# %%
df_reviews = pd.read_parquet(f"gs://{BUCKET_NAME}/raw/reviews/all_beauty_reviews.parquet")
df_reviews.head(5)
# Out:
#    rating                                      title  \
# 0     5.0  Such a lovely scent but not overpowering.
# 1     4.0     Works great but smells a little weird.
# 2     5.0                                       Yes!
# 3     1.0                          Synthetic feeling
# 4     5.0                                         A+
#
#                                                 text images        asin  \
# 0  This spray is really nice. It smells really go...     []  B00YQ6X8EO
# 1  This product does what I need it to do, I just...     []  B081TJ8YS3
# 2                          Smells good, feels great!     []  B07PNNCSP9
# 3                                     Felt synthetic     []  B09JS339BZ
# 4                                            Love it     []  B08BZ63GMJ
#
#   parent_asin                       user_id      timestamp  helpful_vote  \
# 0  B00YQ6X8EO  AGKHLEW2SOWHNMFQIJGBECAF7INQ  1588687728923             0
# ...

# %%
# --- Reviews Inspection ---
print("\n=== REVIEWS SHAPE ===")
print(df_reviews.shape)
# Out:
# === REVIEWS SHAPE ===
# (50, 10)

# %%
print("\n=== REVIEWS RATING DISTRIBUTION ===")
print(df_reviews['rating'].value_counts(dropna=False))
# Out:
# === REVIEWS RATING DISTRIBUTION ===
# rating
# 5.0    29
# 3.0     8
# 4.0     5
# 1.0     5
# 2.0     3
# Name: count, dtype: int64
